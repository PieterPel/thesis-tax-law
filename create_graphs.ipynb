# %% [markdown]
# # Graphs for 'Aandelenopties en belang in de vennootschapsbelasting'

# %% [markdown]
# ## Option payoff plot

# %%
from src.plotting import get_option_payoff_plot
import numpy as np

asset_prices = np.linspace(0, 200, 400)
strike_price = 100
option_price = 10


plt = get_option_payoff_plot(S=asset_prices,
                             K=strike_price,
                             option_price=option_price)

plt.show()

# %% [markdown]
# ## Graphical Black-Scholes price plot

# %%
from src.plotting import get_black_scholes_price_plot

asset_price = 100
strike_price = 90
tau = 1
risk_free_rate = 0.02
sigma = 0.1
option_type = "call"

plt = get_black_scholes_price_plot(S0=asset_price,
                                   K=strike_price,
                                   T=tau,
                                   r=risk_free_rate,
                                   sigma=sigma,
                                   option_type=option_type)

plt.show()
# Out:
# Calculated area under the product curve by integration: 3.807243360752824e-07

# %% [markdown]
# ## Deltamethod and price method comparison 1

# %%
from src.plotting import get_method_compare_plot

asset_prices = np.linspace(0, asset_price*10, 100)
strike_price = 75
tau = 5
rf_rate = 0.02
sigma = 0.2

plt = get_method_compare_plot(asset_prices=asset_prices,
                              strike_price=strike_price,
                              tau=tau,
                              rf_rate=rf_rate,
                              sigma=sigma)
# Out:
# c:\Users\pelpi\Documents\Repositories\thesis-tax-law\src\black_scholes.py:18: RuntimeWarning: divide by zero encountered in log
#   d1 = (np.log(S / K) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
# c:\Users\pelpi\Documents\Repositories\thesis-tax-law\src\black_scholes.py:69: RuntimeWarning: divide by zero encountered in log
#   d1 = (np.log(S / K) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
# c:\Users\pelpi\Documents\Repositories\thesis-tax-law\src\plotting.py:266: RuntimeWarning: invalid value encountered in scalar divide
#   (bs_price) / (asset_price)

# %% [markdown]
# ## Deltamethod and price method comparison 2

# %%
from src.plotting import get_realised_economic_percentage_plot

# Parameters
asset_price = 100  # Initial asset price
strike_price = 100  # Strike price of the option
tau = 1  # Time to expiry (in years)
rf_rate = 0.04  # Risk-free rate (annual)
sigma = 0.1  # Volatility (annualized)

# Future stock prices
prices_at_expiry = np.linspace(0, asset_price * 2, 100)

plt = get_realised_economic_percentage_plot(asset_price=asset_price,
                                            strike_price=strike_price,
                                            tau=tau,
                                            rf_rate=rf_rate,
                                            sigma=sigma)

plt.show()
# Out:
# c:\Users\pelpi\Documents\Repositories\thesis-tax-law\src\black_scholes.py:18: RuntimeWarning: divide by zero encountered in log
#   d1 = (np.log(S / K) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
# c:\Users\pelpi\Documents\Repositories\thesis-tax-law\src\plotting.py:352: RuntimeWarning: divide by zero encountered in divide
#   pdf = (1 / (prices_at_expiry * std * np.sqrt(2 * np.pi))) * np.exp(
# c:\Users\pelpi\Documents\Repositories\thesis-tax-law\src\plotting.py:353: RuntimeWarning: divide by zero encountered in log
#   -((np.log(prices_at_expiry) - mu) ** 2) / (2 * std**2)
# c:\Users\pelpi\Documents\Repositories\thesis-tax-law\src\plotting.py:352: RuntimeWarning: invalid value encountered in multiply
#   pdf = (1 / (prices_at_expiry * std * np.sqrt(2 * np.pi))) * np.exp(
